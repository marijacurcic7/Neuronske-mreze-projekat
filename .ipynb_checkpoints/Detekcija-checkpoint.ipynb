# %%
import pandas as pd
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
df = pd.read_csv('kuzushiji_resized/traincsv.csv')

# %%
df
# Out:
#                image_id                                             labels
# 0     100241706_00004_2  U+306F 586.824459234609 1728.922302529685 66.3...
# 1     100241706_00005_1  U+306F 520.7784280936455 1006.916365513681 51....
# 2     100241706_00005_2  U+306F 271.3211920529801 686.5792462570986 62....
# 3     100241706_00006_1  U+3082 705.9398814563929 1496.7568193515183 32...
# 4     100241706_00007_2  U+309D 575.3954849498328 1473.7375904860394 13...
# ...                 ...                                                ...
# 3600        umgy012-038  U+30FD 582.3062645011602 526.0948453608247 15....
# 3601        umgy012-039  U+309D 271.0694058856191 301.65913757700207 19...
# 3602        umgy012-040  U+30DE 441.0699260943718 216.91523678792038 45...
# 3603        umgy012-041  U+309D 982.640650406504 526.942895989123 10.51...
# 3604        umgy012-042  U+4E00 680.5995475113123 590.8216473791696 56....
#
# [3605 rows x 2 columns]

# %%
cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
for index, row in df.iterrows():
    image_id = row[0]
    labels = row[1]

    filename = 'kuzushiji_resized/train_images/'+image_id+'.jpg'
    img = cv2.imread(filename)
#     plt.imshow(img)

    ss.setBaseImage(img)
    ss.switchToSelectiveSearchFast()
    rects = ss.process()
    imOut = img.copy()
    for i, rect in (enumerate(rects)):
        x, y, w, h = rect
    #     print(x,y,w,h)
    #     imOut = imOut[x:x+w,y:y+h]
        cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
    # plt.figure()
    plt.figure(figsize=(10,10))
    plt.imshow(imOut)
    break

# %%
len(rects)
# Out:
# 4577

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']
    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    intersection_area = (x_right - x_left) * (y_bottom - y_top)
    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])
    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
train_images=[]
train_labels=[]
for index, row in df[:200].iterrows():
    try:
        image_id = row[0]
        labels = row[1]
        filename = 'kuzushiji_resized/train_images/'+image_id+'.jpg'
        print(index, filename)
        image = cv2.imread(filename)
        
        ls = labels.split(' ')
        index = len(ls) - 1
        ls1 = ls[:index]
        labels1 = np.array(ls1).reshape(-1, 5)
        gtvalues=[]
        for codepoint, x1, y1, w1, h1 in labels1:
            x1, y1, w1, h1 = float(x1), float(y1), float(w1), float(h1)
            x2 = x1 + w1
            y2 = y1 + h1
            gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
                
        ss.setBaseImage(image)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = image.copy()
        counter = 0
        falsecounter = 0
        flag = 0
        fflag = 0
        bflag = 0
        for e, result in enumerate(ssresults):
            if flag == 0:
                for gtval in gtvalues:
                    x,y,w,h = result
                    iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                    if counter < 30:
                        if iou > 0.70:
#                             print("nasao")
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (100,100), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(1)
                            counter += 1
                    else :
                        fflag =1
                    if falsecounter <30:
                        if iou < 0.3:
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (100,100), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(0)
                            falsecounter += 1
                    else :
                        bflag = 1
                if fflag == 1 and bflag == 1:
#                     print("inside")
                    flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue
# Out:
# 0 kuzushiji_resized/train_images/100241706_00004_2.jpg
# inside
# 1 kuzushiji_resized/train_images/100241706_00005_1.jpg
# inside
# 2 kuzushiji_resized/train_images/100241706_00005_2.jpg
# inside
# 3 kuzushiji_resized/train_images/100241706_00006_1.jpg
# inside
# 4 kuzushiji_resized/train_images/100241706_00007_2.jpg
# inside
# 5 kuzushiji_resized/train_images/100241706_00008_1.jpg
# inside
# 6 kuzushiji_resized/train_images/100241706_00008_2.jpg
# inside
# 7 kuzushiji_resized/train_images/100241706_00009_1.jpg
# inside
# 8 kuzushiji_resized/train_images/100241706_00009_2.jpg
# inside
# 9 kuzushiji_resized/train_images/100241706_00010_1.jpg
# inside
# 10 kuzushiji_resized/train_images/100241706_00010_2.jpg
# inside
# 11 kuzushiji_resized/train_images/100241706_00011_1.jpg
# inside
# 12 kuzushiji_resized/train_images/100241706_00011_2.jpg
# inside
# 13 kuzushiji_resized/train_images/100241706_00012_1.jpg
# inside
# 14 kuzushiji_resized/train_images/100241706_00012_2.jpg
# inside
# 15 kuzushiji_resized/train_images/100241706_00013_1.jpg
# inside
# 16 kuzushiji_resized/train_images/100241706_00013_2.jpg
# inside
# 17 kuzushiji_resized/train_images/100241706_00014_1.jpg
# inside
# 18 kuzushiji_resized/train_images/100241706_00014_2.jpg
# inside
# 19 kuzushiji_resized/train_images/100241706_00015_1.jpg
# inside
# 20 kuzushiji_resized/train_images/100241706_00015_2.jpg
# inside
# 21 kuzushiji_resized/train_images/100241706_00016_1.jpg
# inside
# 22 kuzushiji_resized/train_images/100241706_00016_2.jpg
# inside
# 23 kuzushiji_resized/train_images/100241706_00017_1.jpg
# inside
# 24 kuzushiji_resized/train_images/100241706_00017_2.jpg
# inside
# 25 kuzushiji_resized/train_images/100241706_00018_1.jpg
# inside
# 26 kuzushiji_resized/train_images/100241706_00018_2.jpg
# inside
# 27 kuzushiji_resized/train_images/100241706_00019_1.jpg
# inside
# 28 kuzushiji_resized/train_images/100241706_00019_2.jpg
# inside
# 29 kuzushiji_resized/train_images/100241706_00020_1.jpg
# inside
# 30 kuzushiji_resized/train_images/100241706_00020_2.jpg
# inside
# 31 kuzushiji_resized/train_images/100241706_00021_1.jpg
# inside
# 32 kuzushiji_resized/train_images/100241706_00021_2.jpg
# inside
# 33 kuzushiji_resized/train_images/100241706_00022_1.jpg
# inside
# 34 kuzushiji_resized/train_images/100241706_00022_2.jpg
# inside
# 35 kuzushiji_resized/train_images/100241706_00023_1.jpg
# inside
# 36 kuzushiji_resized/train_images/100241706_00023_2.jpg
# inside
# 37 kuzushiji_resized/train_images/100241706_00024_1.jpg
# inside
# 38 kuzushiji_resized/train_images/100241706_00024_2.jpg
# inside
# 39 kuzushiji_resized/train_images/100241706_00025_1.jpg
# inside
# 40 kuzushiji_resized/train_images/100241706_00025_2.jpg
# inside
# 41 kuzushiji_resized/train_images/100241706_00026_1.jpg
# inside
# 42 kuzushiji_resized/train_images/100241706_00026_2.jpg
# inside
# 43 kuzushiji_resized/train_images/100241706_00027_1.jpg
# inside
# 44 kuzushiji_resized/train_images/100241706_00027_2.jpg
# inside
# 45 kuzushiji_resized/train_images/100241706_00028_1.jpg
# inside
# 46 kuzushiji_resized/train_images/100241706_00028_2.jpg
# inside
# 47 kuzushiji_resized/train_images/100241706_00029_1.jpg
# inside
# 48 kuzushiji_resized/train_images/100241706_00029_2.jpg
# inside
# 49 kuzushiji_resized/train_images/100241706_00030_1.jpg
# inside
# 50 kuzushiji_resized/train_images/100241706_00030_2.jpg
# inside
# 51 kuzushiji_resized/train_images/100241706_00031_1.jpg
# inside
# 52 kuzushiji_resized/train_images/100241706_00031_2.jpg
# inside
# 53 kuzushiji_resized/train_images/100241706_00032_1.jpg
# inside
# 54 kuzushiji_resized/train_images/100241706_00032_2.jpg
# inside
# 55 kuzushiji_resized/train_images/100241706_00033_1.jpg
# inside
# 56 kuzushiji_resized/train_images/100241706_00033_2.jpg
# inside
# 57 kuzushiji_resized/train_images/100241706_00034_1.jpg
# inside
# 58 kuzushiji_resized/train_images/100241706_00034_2.jpg
# inside
# 59 kuzushiji_resized/train_images/100241706_00035_1.jpg
# inside
# 60 kuzushiji_resized/train_images/100241706_00035_2.jpg
# inside
# 61 kuzushiji_resized/train_images/100241706_00036_1.jpg
# inside
# 62 kuzushiji_resized/train_images/100241706_00036_2.jpg
# inside
# 63 kuzushiji_resized/train_images/100241706_00037_1.jpg
# inside
# 64 kuzushiji_resized/train_images/100241706_00037_2.jpg
# inside
# 65 kuzushiji_resized/train_images/100241706_00038_1.jpg
# inside
# 66 kuzushiji_resized/train_images/100249371_00002_1.jpg
# inside
# 67 kuzushiji_resized/train_images/100249371_00002_2.jpg
# inside
# 68 kuzushiji_resized/train_images/100249371_00003_1.jpg
# inside
# 69 kuzushiji_resized/train_images/100249371_00004_2.jpg
# inside
# 70 kuzushiji_resized/train_images/100249371_00005_1.jpg
# inside
# 71 kuzushiji_resized/train_images/100249371_00005_2.jpg
# inside
# 72 kuzushiji_resized/train_images/100249371_00006_1.jpg
# inside
# 73 kuzushiji_resized/train_images/100249371_00006_2.jpg
# inside
# 74 kuzushiji_resized/train_images/100249371_00007_1.jpg
# inside
# 75 kuzushiji_resized/train_images/100249371_00007_2.jpg
# inside
# 76 kuzushiji_resized/train_images/100249371_00008_1.jpg
# inside
# 77 kuzushiji_resized/train_images/100249371_00008_2.jpg
# inside
# 78 kuzushiji_resized/train_images/100249371_00009_1.jpg
# inside
# 79 kuzushiji_resized/train_images/100249371_00009_2.jpg
# inside
# 80 kuzushiji_resized/train_images/100249371_00010_1.jpg
# inside
# 81 kuzushiji_resized/train_images/100249371_00011_1.jpg
# inside
# 82 kuzushiji_resized/train_images/100249371_00011_2.jpg
# inside
# 83 kuzushiji_resized/train_images/100249371_00012_1.jpg
# inside
# 84 kuzushiji_resized/train_images/100249371_00012_2.jpg
# inside
# 85 kuzushiji_resized/train_images/100249371_00013_1.jpg
# inside
# 86 kuzushiji_resized/train_images/100249371_00013_2.jpg
# inside
# 87 kuzushiji_resized/train_images/100249371_00014_1.jpg
# inside
# 88 kuzushiji_resized/train_images/100249371_00014_2.jpg
# inside
# 89 kuzushiji_resized/train_images/100249371_00015_1.jpg
# inside
# 90 kuzushiji_resized/train_images/100249371_00015_2.jpg
# inside
# 91 kuzushiji_resized/train_images/100249371_00016_1.jpg
# inside
# 92 kuzushiji_resized/train_images/100249371_00016_2.jpg
# inside
# 93 kuzushiji_resized/train_images/100249371_00017_1.jpg
# inside
# 94 kuzushiji_resized/train_images/100249371_00017_2.jpg
# inside
# 95 kuzushiji_resized/train_images/100249371_00018_1.jpg
# inside
# 96 kuzushiji_resized/train_images/100249371_00019_1.jpg
# inside
# 97 kuzushiji_resized/train_images/100249371_00019_2.jpg
# inside
# 98 kuzushiji_resized/train_images/100249371_00020_1.jpg
# inside
# 99 kuzushiji_resized/train_images/100249371_00020_2.jpg
# inside
# 100 kuzushiji_resized/train_images/100249371_00021_1.jpg
# inside
# 101 kuzushiji_resized/train_images/100249371_00021_2.jpg
# inside
# 102 kuzushiji_resized/train_images/100249371_00022_1.jpg
# inside
# 103 kuzushiji_resized/train_images/100249371_00022_2.jpg
# inside
# 104 kuzushiji_resized/train_images/100249371_00023_1.jpg
# inside
# 105 kuzushiji_resized/train_images/100249371_00023_2.jpg
# inside
# 106 kuzushiji_resized/train_images/100249371_00024_1.jpg
# inside
# 107 kuzushiji_resized/train_images/100249371_00024_2.jpg
# inside
# 108 kuzushiji_resized/train_images/100249371_00025_1.jpg
# inside
# 109 kuzushiji_resized/train_images/100249371_00025_2.jpg
# inside
# 110 kuzushiji_resized/train_images/100249371_00026_1.jpg
# inside
# 111 kuzushiji_resized/train_images/100249371_00026_2.jpg
# inside
# 112 kuzushiji_resized/train_images/100249371_00027_1.jpg
# inside
# 113 kuzushiji_resized/train_images/100249371_00027_2.jpg
# inside
# 114 kuzushiji_resized/train_images/100249371_00028_1.jpg
# inside
# 115 kuzushiji_resized/train_images/100249371_00028_2.jpg
# inside
# 116 kuzushiji_resized/train_images/100249371_00029_1.jpg
# inside
# 117 kuzushiji_resized/train_images/100249371_00029_2.jpg
# inside
# 118 kuzushiji_resized/train_images/100249371_00030_1.jpg
# inside
# 119 kuzushiji_resized/train_images/100249371_00031_1.jpg
# inside
# 120 kuzushiji_resized/train_images/100249371_00031_2.jpg
# inside
# 121 kuzushiji_resized/train_images/100249371_00032_1.jpg
# inside
# 122 kuzushiji_resized/train_images/100249371_00032_2.jpg
# inside
# 123 kuzushiji_resized/train_images/100249371_00033_1.jpg
# inside
# 124 kuzushiji_resized/train_images/100249371_00033_2.jpg
# inside
# 125 kuzushiji_resized/train_images/100249371_00034_1.jpg
# inside
# 126 kuzushiji_resized/train_images/100249371_00034_2.jpg
# inside
# 127 kuzushiji_resized/train_images/100249371_00035_1.jpg
# inside
# 128 kuzushiji_resized/train_images/100249371_00035_2.jpg
# inside
# 129 kuzushiji_resized/train_images/100249376_00004_1.jpg
# inside
# 130 kuzushiji_resized/train_images/100249376_00004_2.jpg
# inside
# 131 kuzushiji_resized/train_images/100249376_00005_1.jpg
# inside
# 132 kuzushiji_resized/train_images/100249376_00005_2.jpg
# inside
# 133 kuzushiji_resized/train_images/100249376_00006_1.jpg
# inside
# 134 kuzushiji_resized/train_images/100249376_00006_2.jpg
# inside
# 135 kuzushiji_resized/train_images/100249376_00007_1.jpg
# inside
# 136 kuzushiji_resized/train_images/100249376_00007_2.jpg
# inside
# 137 kuzushiji_resized/train_images/100249376_00008_1.jpg
# inside
# 138 kuzushiji_resized/train_images/100249376_00008_2.jpg
# inside
# 139 kuzushiji_resized/train_images/100249376_00009_1.jpg
# inside
# 140 kuzushiji_resized/train_images/100249376_00009_2.jpg
# inside
# 141 kuzushiji_resized/train_images/100249376_00010_1.jpg
# inside
# 142 kuzushiji_resized/train_images/100249376_00010_2.jpg
# inside
# 143 kuzushiji_resized/train_images/100249376_00011_1.jpg
# inside
# 144 kuzushiji_resized/train_images/100249376_00011_2.jpg
# inside
# 145 kuzushiji_resized/train_images/100249376_00012_1.jpg
# inside
# 146 kuzushiji_resized/train_images/100249376_00012_2.jpg
# inside
# 147 kuzushiji_resized/train_images/100249376_00013_1.jpg
# inside
# 148 kuzushiji_resized/train_images/100249376_00013_2.jpg
# inside
# 149 kuzushiji_resized/train_images/100249376_00014_1.jpg
# inside
# 150 kuzushiji_resized/train_images/100249376_00014_2.jpg
# inside
# 151 kuzushiji_resized/train_images/100249376_00015_1.jpg
# inside
# 152 kuzushiji_resized/train_images/100249376_00015_2.jpg
# inside
# 153 kuzushiji_resized/train_images/100249376_00016_1.jpg
# inside
# 154 kuzushiji_resized/train_images/100249376_00016_2.jpg
# inside
# 155 kuzushiji_resized/train_images/100249376_00017_1.jpg
# inside
# 156 kuzushiji_resized/train_images/100249376_00017_2.jpg
# inside
# 157 kuzushiji_resized/train_images/100249376_00018_1.jpg
# inside
# 158 kuzushiji_resized/train_images/100249376_00018_2.jpg
# inside
# 159 kuzushiji_resized/train_images/100249376_00019_1.jpg
# inside
# 160 kuzushiji_resized/train_images/100249376_00019_2.jpg
# inside
# 161 kuzushiji_resized/train_images/100249376_00020_1.jpg
# inside
# 162 kuzushiji_resized/train_images/100249376_00020_2.jpg
# inside
# 163 kuzushiji_resized/train_images/100249376_00021_1.jpg
# inside
# 164 kuzushiji_resized/train_images/100249376_00021_2.jpg
# inside
# 165 kuzushiji_resized/train_images/100249376_00022_1.jpg
# inside
# 166 kuzushiji_resized/train_images/100249376_00022_2.jpg
# inside
# 167 kuzushiji_resized/train_images/100249376_00023_1.jpg
# inside
# 168 kuzushiji_resized/train_images/100249376_00023_2.jpg
# inside
# 169 kuzushiji_resized/train_images/100249376_00024_1.jpg
# inside
# 170 kuzushiji_resized/train_images/100249376_00024_2.jpg
# inside
# 171 kuzushiji_resized/train_images/100249376_00025_1.jpg
# inside
# 172 kuzushiji_resized/train_images/100249376_00025_2.jpg
# inside
# 173 kuzushiji_resized/train_images/100249376_00026_1.jpg
# inside
# 174 kuzushiji_resized/train_images/100249376_00026_2.jpg
# inside
# 175 kuzushiji_resized/train_images/100249376_00027_1.jpg
# inside
# 176 kuzushiji_resized/train_images/100249376_00027_2.jpg
# inside
# 177 kuzushiji_resized/train_images/100249376_00028_1.jpg
# inside
# 178 kuzushiji_resized/train_images/100249376_00028_2.jpg
# inside
# 179 kuzushiji_resized/train_images/100249376_00029_1.jpg
# inside
# 180 kuzushiji_resized/train_images/100249376_00029_2.jpg
# inside
# 181 kuzushiji_resized/train_images/100249376_00030_1.jpg
# inside
# 182 kuzushiji_resized/train_images/100249376_00030_2.jpg
# inside
# 183 kuzushiji_resized/train_images/100249376_00031_1.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#      22 ss.setBaseImage(image)
#      23 ss.switchToSelectiveSearchFast()
# ---> 24 ssresults = ss.process()
#      25 imout = image.copy()
#      26 counter = 0
#
# KeyboardInterrupt:

# %%
len(train_images)

# %%
im1 = train_images[50]
plt.imshow(im1)

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)

# %%
X_new.shape

# %%
y_new.shape

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.svm import SVC
from sklearn import metrics

from keras.models import Sequential, Model,load_model
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, Conv3D, BatchNormalization, MaxPool2D, MaxPooling2D, AveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

from keras.callbacks import ModelCheckpoint
from datetime import datetime

from keras import backend as K

# %%
leinst = LabelEncoder()
yyinst = leinst.fit_transform(y_new)

x_train, x_test, y_train, y_test = train_test_split(X_new, yyinst, test_size=0.2, shuffle=True, random_state=42)

x_test, x_validation, y_test, y_validation = train_test_split(x_test, y_test, test_size=0.5, shuffle=True, random_state=42)


print(x_train.shape)
print(x_test.shape)
print(x_validation.shape)


num_classes = len(leinst.classes_)
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)
y_validation = to_categorical(y_validation, num_classes=num_classes)

# %%
num_classes

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(100,100,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(2, activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()

# %%
num_epochs = 10
batch_size = 32

checkpointer = ModelCheckpoint(filepath="best_weights_rcnn.hdf5", verbose=1, save_best_only=True)

start = datetime.now()
model.fit(x_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(x_validation, y_validation), 
           callbacks=[checkpointer], verbose=1)

duration = datetime.now() - start
print("Training completed in: ", duration)

# %%
train_score = model.evaluate(x_train, y_train, verbose=1)
print("Training Accuracy: ", train_score[1])

# %%
test_score = model.evaluate(x_test, y_test, verbose=1)
print("Test Accuracy: ", test_score[1])
